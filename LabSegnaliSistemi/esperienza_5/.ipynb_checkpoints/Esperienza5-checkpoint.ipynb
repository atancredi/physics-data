# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

# %%
#frequenze suggerite
print(np.logspace(1,2.8, 4, base=10).round(-1))
print(np.logspace(2.8,5.5, 20,base=10).round(-1)[1:])

#frequenze intorno alla frequenza di taglio
print([500,750,800,950,1000,1050,1100,1150,1300,1500])
# Out:
# [ 10.  40. 160. 630.]
# [   880.   1210.   1680.   2340.   3240.   4490.   6230.   8650.  11990.
#   16640.  23080.  32010.  44400.  61580.  85420. 118490. 164360. 227980.
#  316230.]
# [500, 750, 800, 950, 1000, 1050, 1100, 1150, 1300, 1500]

# %% [markdown]
# # Parte 1 - K=2.5

# %%
#freq = [np.hstack((np.array([9.625,26.15,39.931,60.762,98.36,157.3,306.06,496.5,564.28,629.15,755.00,886.20,938.86])*10**-3,
#                   np.array([1.0580,1.215,1.3025,1.5008,1.6158,2.2816,3.2393,4.4964,6.246,8.536,11.023,14.309]))),"Frequenza (kHz)"] #kHz
#vin = [np.array([0.980,0.96,0.98,0.98,0.98,0.96,0.96,0.96,0.96,0.96,0.96,0.96,1.01,
#                 0.98,0.96,0.98,0.96,1.01,0.96,0.98,0.98,0.96,0.98,0.96,0.96]),"Vin(V)"] #V
#vout = [np.array([2.27,2.27,2.27,2.27,2.29,2.29,2.43,2.73,2.93,3.14,3.62,4.00,4.00,
#                  3.58,2.65,2.21,1.51,1.25,0.58,0.34,0.22,0.16,0.14,0.12,0.12]),"Vout(V)"] #V
#deltat = [-1*np.array([35,35,120,56,86,128,93.04,105.8,119.44,122.9,153.6,206.1,221.6,
#                    262.96,277.8,283.2,267.92,256.8,186.96,139.74,108.29,78.78,53.63,6.53,7.63]),"\u03BCs"] #us

#print(len(freq[0]))
#print(len(vin[0]))
#print(len(vout[0]))
#print(len(deltat[0]))
# Out:
# 25
# 25
# 25
# 25

# %% [markdown]
# # Parte 2 - K circa 1.6

# %%
vin = [np.array([0.95,0.95,0.96,0.95,0.95,0.96,0.96,0.95,0.96,0.96,0.96,0.95,0.96,0.96,0.95,0.95,0.96,0.96,0.96,0.95,0.96,0.96]),"Vin (V)"]
vout = [np.array([0.95,0.95,0.95,0.95,0.93,0.93,0.9,0.84,0.810,0.8,0.75,0.7,0.68,0.64,0.59,0.56,0.52,0.5,0.39,0.29,0.2,0.16]),"Vout (V)"]
freq = [np.hstack((np.array([9.927,27.06,40.96,59.78,93.05,156.94,302.4,499.4,563.8,621,755.7,885.3,959])*10**-3,
                 np.array([1.0638,1.2105,1.3191,1.4880,1.6224,2.2875,3.2337,4.8730]))),"Frequenza (kHz)"]
deltat = [-1*np.array([100,124,152,144,167,166.4,159.2,158.4,153.6,154.4,148.8,141.6,132.8,135.2,122.37,118.88,111.42,107.5,89.44,71.14,53.31]),"\u03BCs"]

print(len(freq[0]))
print(len(vin[0]))
print(len(vout[0]))
print(len(deltat[0]))
# Out:
# 17
# 17
# 17
# 17

# %%
fig = len(plt.get_fignums())
plt.figure(fig)
module = vout[0]/vin[0]
plt.xscale("log")
plt.scatter(freq[0],20*np.log(module), label="dati raccolti")
plt.axhline(-3, color="red", label="-3dB")
#plt.axvline(71050, label="$\\nu_C$ teorica", color="green")
plt.legend()
plt.xlabel("$\\nu$ (Hz)")
plt.ylabel("Attenuazione (dB)")
plt.grid()
plt.title("Diagramma di Bode, Funzione di trasferimento")
freq_act = freq[0]*10**3
deltat_act = deltat[0]*(10**-6)  #us
delta_phi = ((2*np.pi*freq_act*deltat_act)*(180/np.pi))
fig = len(plt.get_fignums())
plt.figure(fig)
plt.xscale("log")
plt.scatter(freq_act, delta_phi, label="Dati raccolti")
#plt.ylim(0,99)
plt.xlabel("$\\nu$ (Hz)")
plt.grid()
plt.axhline(-45, label="- 45°", color="red")
#plt.axvline(71050, label="$\\nu_C$ teorica", color="green")
plt.ylabel("Sfasamento (Deg)")
plt.legend()
plt.title("Diagramma di Bode, fase")
# Out:
# Text(0.5, 1.0, 'Diagramma di Bode, fase')

# %%
#gli RMS dipendono dalla tensione di alimentazione dell'OP-AMP
